# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrew-s-Andersen/Statistical-Quality-Control/blob/main/SQCLab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
import scipy
import statistics
import numpy as np
import scipy.stats
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import plotly.graph_objects as go
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp as mc
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from scipy.stats import f_oneway

data125 = [2.7,2.6,4.6,3.2,3.0,3.8]
data160 = [4.6,4.9,5.0,4.2,3.6,4.2]
data200 = [4.6,2.9,3.4,3.5,4.1,5.1]
# Acquiring F Statistic and P value
stat, p = f_oneway(data125, data160, data200)
print( 'stat=%.3f, p=%.3f' % (stat, p))
# Out:
# stat=3.586, p=0.053

# %%
import math
import random
import scipy
import statistics
import numpy as np
import scipy.stats
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import plotly.graph_objects as go
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp as mc
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from scipy.stats import f_oneway
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-3ed39ff2-0681-42a5-b823-6cc0dd8c630d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ed39ff2-0681-42a5-b823-6cc0dd8c630d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !cat SQC\ Lab3\ -\ Sheet1.csv
# Out:
# Observation,Flow Rate,Uniformity
# 1,125,2.7
# 2,125,2.6
# 3,125,4.6
# 4,125,3.2
# 5,125,3
# 6,125,3.8
# 1,160,4.6
# 2,160,4.9
# 3,160,5
# 4,160,4.2
# 5,160,3.6
# 6,160,4.2
# 1,200,4.6
# 2,200,2.9
# 3,200,3.4
# 4,200,3.5
# 5,200,4.1
# 6,200,5.1

# %%
#Generation of Anova Table
import pandas as pd
import math
import random
import scipy
import statistics
import numpy as np
import scipy.stats
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import plotly.graph_objects as go
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp as mc
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from scipy.stats import f_oneway


df = pd.DataFrame({"a":[2.7, 2.6, 4.6, 3.2, 3.0, 3.8],
                         "b":[4.6, 4.9, 5.0, 4.2, 3.6, 4.2],
                        "c":[4.6, 2.9, 3.4, 3.5, 4.1, 5.1]})
 

model = ols( data = df).fit()
aov_table = sm.stats.anova_lm(model, typ=2)
aov_table
# Out:
#      a    b    c
# 0  2.7  4.6  4.6
# 1  2.6  4.9  2.9
# 2  4.6  5.0  3.4
# 3  3.2  4.2  3.5
# 4  3.0  3.6  4.1
# 5  3.8  4.2  5.1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0882019cee70> in <module>
#      25
#      26 print(df)
# ---> 27 model = ols( data = df).fit()
#      28 aov_table = sm.stats.anova_lm(model, typ=2)
#      29 aov_table
#
# TypeError: from_formula() missing 1 required positional argument: 'formula'

# %%
import pandas as pd
data1 = pd.read_csv('SQC Lab3 - Sheet1.csv', sep=';', na_values=".")
data1
# Out:
#    Observation,Flow Rate,Uniformity
# 0                         1,125,2.7
# 1                         2,125,2.6
# 2                         3,125,4.6
# 3                         4,125,3.2
# 4                           5,125,3
# 5                         6,125,3.8
# 6                         1,160,4.6
# 7                         2,160,4.9
# 8                           3,160,5
# 9                         4,160,4.2
# 10                        5,160,3.6
# 11                        6,160,4.2
# 12                        1,200,4.6
# 13                        2,200,2.9
# 14                        3,200,3.4
# 15                        4,200,3.5
# 16                        5,200,4.1
# 17                        6,200,5.1

# %%
model = ols('Flow Rate ~ Uniformity', data = data1).fit()
aov_table = sm.stats.anova_lm(model, typ = 2)
aov_table
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-21-5add206c00a2>", line 1, in <module>
#     model = ols('Flow Rate ~ Uniformity', data = data1).fit()
#
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py", line 170, in from_formula
#     missing=missing)
#
#   File "/usr/local/lib/python3.7/dist-packages/statsmodels/formula/formulatools.py", line 64, in handle_formula_data
#     NA_action=na_action)
#
#   File "/usr/local/lib/python3.7/dist-packages/patsy/highlevel.py", line 310, in dmatrices
#     NA_action, return_type)
#
#   File "/usr/local/lib/python3.7/dist-packages/patsy/highlevel.py", line 165, in _do_highlevel_design
#     NA_action)
#
#   File "/usr/local/lib/python3.7/dist-packages/patsy/highlevel.py", line 70, in _try_incr_builders
#     NA_action)
#
# ...
